# %%
from scipy.stats import gamma
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(gamma.ppf(0.01, a),
                gamma.ppf(0.99, a), 100)

# %%
gamma()

# %%
rv = gamma(2,0,3)
x = np.linspace(0,30,1000)
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
rv.ppf(0.5)
# Out:
# 1.6783469900166612

# %%
gamma.ppf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-29014223922d> in <module>
# ----> 1 gamma.ppf()
#
# TypeError: ppf() missing 1 required positional argument: 'q'

# %%
import numpy as np
from scipy.stats import gamma
from matplotlib import pyplot as plt

alpha_values = [1, 2, 3, 3, 3]
beta_values = [0.5, 0.5, 0.5, 1, 2]
color = ['b','r','g','y','m']
x = np.linspace(1E-6, 10, 1000)

fig, ax = plt.subplots(figsize=(8, 5))

for k, t, c in zip(alpha_values, beta_values, color):
    dist = gamma(k, 0, t)
    plt.plot(x, dist.pdf(x), c=c, label=r'$\alpha=%.1f,\ \theta=%.1f$' % (k, t))

plt.xlim(0, 10)
plt.ylim(0, 2)

plt.xlabel('$x$')
plt.ylabel(r'$p(x|\alpha,\beta)$')
plt.title('Gamma Distribution')

plt.legend(loc=0)
plt.show()

# %%
rv =  gamma(1.2, 0, 2)
rv2 =  gamma(2.5, 0, 2)
plt.plot(x,rv.pdf(x),label='theta 1')
plt.plot(x,rv2.pdf(x),label='theta 5')
plt.legend()

# %%
rv2.cdf(0.5)
# Out:
# 0.19874804309879915

# %%
rv2.ppf(0.5)
# Out:
# 1.1829869421876689

# %%
NUM_SAMPLES = 100000
SKEW_PARAMS = [3]
class SkewNormalDsitribution:
    def __init__(self,local,skew,scale):
        self.local = local
        self.skew=skew
        self.scale=scale
        
    def pdf(self,x):
        # adapated from:
        # http://stackoverflow.com/questions/5884768/skew-normal-distribution-in-scipy
        t = (x-self.local) / self.scale
        return 2.0 * self.scale * stats.norm.pdf(t) * stats.norm.cdf(self.skew*t)
    
    

def skew_norm_pdf(x,e=0,w=1,a=0):
    # adapated from:
    # http://stackoverflow.com/questions/5884768/skew-normal-distribution-in-scipy
    t = (x-e) / w
    return 2.0 * w * stats.norm.pdf(t) * stats.norm.cdf(a*t)
# generate the skew normal PDF for reference:
location = 0.0
scale = [5]
x = np.linspace(-5,20,100) 

plt.subplots(figsize=(9,6))
for alpha_skew,sc in zip(SKEW_PARAMS,scale):
    p = skew_norm_pdf(x,location,sc,alpha_skew)
    # n.b. note that alpha is a parameter that controls skew, but the 'skewness'
    # as measured will be different. see the wikipedia page:
    # https://en.wikipedia.org/wiki/Skew_normal_distribution
    plt.plot(x,p,label=f'skew={alpha_skew} scale={sc}')
    plt.legend()

# %%
sd = SkewNormalDsitribution(local=0,scale=5,skew=3)

# %%
sd.pdf(8)
# Out:
# 1.1092074668283476

# %%
plt.plot(x,np.log(x+1))
# plt.xticks([])
plt.vlines(0,-10,10)
plt.hlines(0,-10,10)
plt.show()
# Out:
# d:\envs\xylab\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
