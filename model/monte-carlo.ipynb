# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
n=10000

x = np.random.rand(n,2)
inside = x[np.sqrt(x[:,0]**2+x[:,1]**2) < 1]
estimate = 4*inside.shape[0] / x.shape[0]
print(f"estimate value of pi {estimate}")
sns.scatterplot(x[:,0],x[:,1])
sns.scatterplot(inside[:,0],inside[:,1])
# plt.ioff()
# fig.show()
# Out:
# estimate value of pi 3.1572
# d:\envs\xylab\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# d:\envs\xylab\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:>

# %%
x
# Out:
# array([[0.52200094, 0.82374261],
#        [0.96963217, 0.97835662],
#        [0.87835227, 0.967308  ],
#        ...,
#        [0.6750091 , 0.26488012],
#        [0.03797762, 0.374047  ],
#        [0.26915432, 0.66898517]])
