# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
import os

# %%
data_dir = os.getcwd()
df=pd.read_csv(os.path.join(os.path.dirname(data_dir),"TSLA.csv"))
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-07-10   52.444000   52.599998   51.563999   51.830002   51.830002
# 1     2015-07-13   52.450001   52.509998   51.209999   52.431999   52.431999
# 2     2015-07-14   52.419998   53.198002   52.102001   53.130001   53.130001
# 3     2015-07-15   53.348000   53.498001   52.416000   52.627998   52.627998
# 4     2015-07-16   52.844002   53.439999   52.632000   53.335999   53.335999
# ...          ...         ...         ...         ...         ...         ...
# 1254  2020-07-02  244.296005  245.600006  237.119995  241.731995  241.731995
# 1255  2020-07-06  255.337997  275.558014  253.207993  274.316010  274.316010
# 1256  2020-07-07  281.002014  285.899994  267.342010  277.971985  277.971985
# 1257  2020-07-08  281.000000  283.451996  262.268005  273.175995  273.175995
# 1258  2020-07-09  279.398010  281.712006  270.256012  278.855988  278.855988
#
#          Volume
# 0      13054500
# 1      14801500
# 2       9538000
# 3      10108000
# 4       8080000
# ...         ...
# 1254   17250100
# 1255  102849500
# 1256  107448500
# 1257   81556500
# 1258   58588000
#
# [1259 rows x 7 columns]

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 4s 50ms/step - loss: 0.1274
# Epoch 2/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0154
# Epoch 3/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0127
# Epoch 4/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0152
# Epoch 5/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0123
# Epoch 6/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0118
# Epoch 7/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0111
# Epoch 8/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0111
# Epoch 9/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0128
# Epoch 10/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0125
# Epoch 11/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0118
# Epoch 12/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0102
# Epoch 13/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0085
# Epoch 14/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0099
# Epoch 15/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0093
# Epoch 16/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0082
# Epoch 17/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0086
# Epoch 18/100
# 24/24 [==============================] - ETA: 0s - loss: 0.009 - 1s 48ms/step - loss: 0.0097
# Epoch 19/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0084
# Epoch 20/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0081
# Epoch 21/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0068
# Epoch 22/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0090
# Epoch 23/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0070
# Epoch 24/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0068
# Epoch 25/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0066
# Epoch 26/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0060
# Epoch 27/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0069
# Epoch 28/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0060
# Epoch 29/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0062
# Epoch 30/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0068
# Epoch 31/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0064
# Epoch 32/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0065
# Epoch 33/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0068
# Epoch 34/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0053
# Epoch 35/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0062
# Epoch 36/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0053
# Epoch 37/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0057
# Epoch 38/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0051
# Epoch 39/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0054
# Epoch 40/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0050
# Epoch 41/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0048
# Epoch 42/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0053
# Epoch 43/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0053
# Epoch 44/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0061
# Epoch 45/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0050
# Epoch 46/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0043
# Epoch 47/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0050
# Epoch 48/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0052: 0s - loss: 0 - ETA: 0s - loss: 0.0
# Epoch 49/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0045
# Epoch 50/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0042
# Epoch 51/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0044
# Epoch 52/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0045
# Epoch 53/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0043
# Epoch 54/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0047
# Epoch 55/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0040
# Epoch 56/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0042
# Epoch 57/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0043
# Epoch 58/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0047
# Epoch 59/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0038
# Epoch 60/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0044
# Epoch 61/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0038
# Epoch 62/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0041
# Epoch 63/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0038
# Epoch 64/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0040
# Epoch 65/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0039
# Epoch 66/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0038
# Epoch 67/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0038
# Epoch 68/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0034
# Epoch 69/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0031
# Epoch 70/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0033
# Epoch 71/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0040
# Epoch 72/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0035
# Epoch 73/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0037
# Epoch 74/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0034
# Epoch 75/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0037
# Epoch 76/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0036
# Epoch 77/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0039
# Epoch 78/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0034
# Epoch 79/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0039
# Epoch 80/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0036
# Epoch 81/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0032
# Epoch 82/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0031
# Epoch 83/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0036
# Epoch 84/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0031: 0s - loss: 0.003
# Epoch 85/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0032
# Epoch 86/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0033
# Epoch 87/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0034
# Epoch 88/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0034
# Epoch 89/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0037
# Epoch 90/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0029
# Epoch 91/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0037
# Epoch 92/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0034
# Epoch 93/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0032
# Epoch 94/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0029
# Epoch 95/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0027
# Epoch 96/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0027
# Epoch 97/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0029
# Epoch 98/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0029
# Epoch 99/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0024
# Epoch 100/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0029

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
# inputs =  dataset_total.values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 519):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)
# Out:
# (459, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualising the results
plt.plot(df.loc[800:, "Date"],dataset_test.values, color = "red", label = "Real TESLA Stock Price")
plt.plot(df.loc[800:, "Date"],predicted_stock_price, color = 'blue', label = "Predicted TESLA Stock Price")
plt.xticks(np.arange(0,459,50))
print(predicted_stock_price.shape)
# plt.vlines(740,0,100)
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
# Out:
# (459, 1)

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[60:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs =  dataset_total.values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 1259):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
plt.plot(df.loc[60:, "Date"],dataset_test.values, color = "red", label = "Real TESLA Stock Price")
plt.plot(df.loc[60:, "Date"],predicted_stock_price, color = 'blue', label = "Predicted TESLA Stock Price")
plt.xticks(np.arange(0,1119,50))
print(predicted_stock_price.shape)
# plt.vlines(740,0,100)
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
# Out:
# (1199, 60, 1)
# (1199, 1)
